# %%
import pandas as pd

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\users\karth\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (1.10.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (1.5.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (3.7.1)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (1.9.1)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (2.1.2)
# Collecting visions[type_image_path]==0.7.4 (from pandas-profiling)
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (1.23.5)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (0.5.1)
# Requirement already satisfied: phik>=0.11.1 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (0.12.2)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (2.28.2)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\karth\anaconda3\lib\site-packages (from pandas-profiling) (1.8)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\karth\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (22.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\karth\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (3.1)
# Requirement already satisfied: imagehash in c:\users\karth\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\karth\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (9.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\karth\appdata\roaming\python\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karth\appdata\roaming\python\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karth\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\karth\appdata\roaming\python\python39\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\karth\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karth\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\karth\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karth\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\karth\appdata\roaming\python\python39\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\karth\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.0->pandas-profiling) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\karth\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\karth\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.4.1)
# Installing collected packages: visions
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.5
#     Uninstalling visions-0.7.5:
#       Successfully uninstalled visions-0.7.5
# Successfully installed visions-0.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.2.0 requires visions[type_image_path]==0.7.5, but you have visions 0.7.4 which is incompatible.

# %%
# from pandas_profiling import ProfileReport
# prof = ProfileReport(df)
# prof.to_file(output_file='output.html')
