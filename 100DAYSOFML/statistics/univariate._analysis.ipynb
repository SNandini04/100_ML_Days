# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\karth\Downloads\train (1).csv")

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# 1. Countplot

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.countplot(data=df,x='Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# PieChart

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Sex'>

# %% [markdown]
# ## Numerical Data

# %%
#Histogram

import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
# distplot
sns.displot(df['Age'],)

# %%
sns.displot(data=df,x='Age', kde=True)

# %%
# Boxplot
sns.boxplot(df['Fare'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
df.Age.min()
# Out:
# 0.42

# %%
df.Age.max()
# Out:
# 80.0

# %%
df[df['Age']<1]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 78   0.83      0      2  248738   29.0000      NaN        S
# 305  0.92      1      2  113781  151.5500  C22 C26        S
# 469  0.75      2      1    2666   19.2583      NaN        C
# 644  0.75      2      1    2666   19.2583      NaN        C
# ...

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
#A skew value between -1 and +1 is considered excellent. 
# A skew value between -2 and +2 is generally acceptable. 
# A skew value less than -1 or greater than +1 indicates a highly skewed distribution.
# A skew value between -1 and -1/2 or between 1/2 and +1 indicates a moderately skewed distribution.
df.Age.skew()
# Out:
# 0.38910778230082704

# %%
df.Fare.skew()
# Out:
# 4.787316519674893

# %%
sns.displot(data=df,x='Fare',kde=True)

# %% [markdown]
# fare is right skewed which is right also as passanger class 1 will have high fare than passenger class 3

# %%
df[df['Fare']>200]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 527          528         0       1
# 557          558         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...
